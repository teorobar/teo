# %%
import pandas as pd

# %%
data = pd.read_csv("state_data.csv") #51 rows, 4 columns
data
# Out:
#    state   latitude   longitude                  name
# 0     AK  63.588753 -154.493062                Alaska
# 1     AL  32.318231  -86.902298               Alabama
# 2     AR  35.201050  -91.831833              Arkansas
# 3     AZ  34.048928 -111.093731               Arizona
# 4     CA  36.778261 -119.417932            California
# 5     CO  39.550051 -105.782067              Colorado
# 6     CT  41.603221  -73.087749           Connecticut
# 7     DC  38.905985  -77.033418  District of Columbia
# 8     DE  38.910832  -75.527670              Delaware
# 9     FL  27.664827  -81.515754               Florida
# 10    GA  32.157435  -82.907123               Georgia
# 11    HI  19.898682 -155.665857                Hawaii
# 12    IA  41.878003  -93.097702                  Iowa
# 13    ID  44.068202 -114.742041                 Idaho
# 14    IL  40.633125  -89.398528              Illinois
# 15    IN  40.551217  -85.602364               Indiana
# ...

# %%
print(data.head(5))
print(data.tail(5))
#the colums represent the abreviation, latitude, longitude, and name of each state
#the first state is Alaska
#the last state is Wyoming
#52 entries
#They included DC and Puerto Rico
# Out:
#   state   latitude   longitude        name
# 0    AK  63.588753 -154.493062      Alaska
# 1    AL  32.318231  -86.902298     Alabama
# 2    AR  35.201050  -91.831833    Arkansas
# 3    AZ  34.048928 -111.093731     Arizona
# 4    CA  36.778261 -119.417932  California
#    state   latitude   longitude           name
# 47    VT  44.558803  -72.577841        Vermont
# 48    WA  47.751074 -120.740139     Washington
# 49    WI  43.784440  -88.787868      Wisconsin
# 50    WV  38.597626  -80.454903  West Virginia
# 51    WY  43.075968 -107.290284        Wyoming

# %%
median_lat = (data["latitude"].median())
print(median_lat)
median_long = data["longitude"].median()
print(median_long)
# Out:
# 39.4355155
# -89.093198

# %%
data["distance_median_lat"] = abs((data["latitude"]) - (median_lat))

# %%
data["distance_median_long"] = abs((data["longitude"]) - (median_long))

# %%
print(data.shape) #52 rows, 6 columns
# Out:
# (52, 6)

# %%
closest_lat = data['distance_median_lat'].idxmin()
print(data['name'][closest_lat])
print(round(data['distance_median_lat'][closest_lat], 2))
# Out:
# Colorado
# 0.11

# %%
farthest_lat = data['distance_median_lat'].idxmax()
print(data['name'][farthest_lat])
print(round(data['distance_median_lat'][farthest_lat], 2))
# Out:
# Alaska
# 24.15

# %%
closest_long = data['distance_median_long'].idxmin()
print(data['name'][closest_long])
print(round(data['distance_median_long'][closest_long], 2))
# Out:
# Illinois
# 0.31

# %%
farthest_long = data['distance_median_long'].idxmax()
print(data['name'][farthest_long])
print(round(data['distance_median_long'][farthest_long], 2))
# Out:
# Hawaii
# 66.57
